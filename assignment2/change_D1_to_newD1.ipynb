# %%
import pandas as pd
import numpy as np

# %%
dataSet1 = pd.read_csv("D1.data",header=None)
dataSet1.iloc[:,8].unique()
new_list = []
for i in dataSet1.iloc[:,8]:
    if i<=7:
        new_list.append("B")
    elif 7<i<=18:
        new_list.append("Y")
    else:
        new_list.append("O")
new_list
dataSet1 = dataSet1.drop(dataSet1.columns[8],axis=1)
dataSet1[8] = pd.Series(new_list)
dataSet1
#dataSet = dataSet3.iloc[:1000,::].values.tolist()
# Out:
#       0      1      2      3       4       5       6       7  8
# 0     M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500  Y
# 1     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700  B
# 2     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100  Y
# 3     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  Y
# 4     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550  B
# ...  ..    ...    ...    ...     ...     ...     ...     ... ..
# 4172  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  Y
# 4173  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  Y
# 4174  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080  Y
# 4175  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  Y
# 4176  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  Y
#
# [4177 rows x 9 columns]

# %%
dataSet1.to_csv("new_D1.csv")
